# %% [markdown]
# <a href="https://colab.research.google.com/github/SHAKTI-swain/Final-project/blob/main/Movie_Recommendation_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#used libaries in the project
import numpy as np
import pandas as pd
import difflib
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
#connect the dataset to a pandas dataframe
movies_data = pd.read_csv('/content/movies.csv')
movies_data.head()
# Out:
#    index                      title certificate  runtime  \
# 0      1                     Freddy      UA 16+  124 min
# 1      2             An Action Hero           U  130 min
# 2      3                    Kantara          UA  148 min
# 3      4  Khakee: The Bihar Chapter      UA 13+   45 min
# 4      5                 Drishyam 2          UA  140 min
#
#                                   genre  \
# 0  Drama, Mystery, Thriller
# 1                    Action
# 2  Action, Adventure, Drama
# 3      Action, Crime, Drama
# 4     Crime, Drama, Mystery
#
#                                                 desc  rating   votes
# 0  The lines between love and obsession blur in t...     7.9  16,441
# 1  Youth Icon. Superstar. Action Hero. At the age...     8.1  15,690
# 2  It involves culture of Kambala and Bhootha Kol...     8.7  78,358
# 3  As a righteous cop pursues a merciless crimina...     8.3   4,464
# 4  A gripping tale of an investigation and a fami...     8.6  18,743

# %%
#no. of rows and columns in the data frame
movies_data.shape
# Out:
# (10000, 8)

# %%
#selecting the relevant features for recommendation
selected_features = ['genre','desc','rating','votes']
print(selected_features)
# Out:
# ['genre', 'desc', 'rating', 'votes']

# %%
#replacing the null values with null string

for feature in selected_features:
     movies_data[feature] = movies_data[feature].fillna('')

# %%
# Combine existing features, handling potential missing columns
combined_features = movies_data['genre'].astype(str) + ' ' + movies_data['desc'].astype(str) + ' ' + movies_data['rating'].astype(str) + ' ' + movies_data['votes'].astype(str)
print(combined_features)
# Out:
# 0       Drama, Mystery, Thriller             The lines...
# 1       Action             Youth Icon. Superstar. Acti...
# 2       Action, Adventure, Drama             It involv...
# 3       Action, Crime, Drama             As a righteou...
# 4       Crime, Drama, Mystery             A gripping t...
#                               ...
# 9995                 Action, Comedy, Drama
# 9996                         Drama, Family
# 9997             Action, Adventure, Comedy
# 9998                                 Drama
# 9999                                 Crime
# Length: 10000, dtype: object

# %%
#converting the text data to feature vectors
vectorizer= TfidfVectorizer()

# %%
feature_vectors= vectorizer.fit_transform(combined_features)
print(feature_vectors)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 237733 stored elements and shape (10000, 19837)>
#   Coords	Values
#   (0, 6016)	0.058099007077201927
#   (0, 11931)	0.14502822017681893
#   (0, 18051)	0.21316170457084885
#   (0, 17953)	0.05987953209629127
#   (0, 10534)	0.29737142109803744
#   (0, 3035)	0.16428272722180703
#   (0, 10682)	0.11417557536279699
#   (0, 1976)	0.12496979955940776
#   (0, 12491)	0.2661221738271596
#   (0, 3333)	0.3204429634844519
#   (0, 8783)	0.0715429355719832
#   (0, 18016)	0.14690747218971667
#   (0, 15179)	0.21694498267934328
#   (0, 12802)	0.30500961443490276
#   (0, 19576)	0.0929310044038085
#   (0, 18725)	0.31457547649130546
#   (0, 18493)	0.2567258591432835
#   (0, 16137)	0.29737142109803744
#   (0, 18465)	0.1909820916907644
#   (0, 181)	0.21909602514665963
#   (0, 605)	0.3094928280704285
#   (1, 17953)	0.07677830879682826
#   (1, 8783)	0.1375999128736728
#   (1, 1448)	0.1140316883409368
#   (1, 19766)	0.15369802066008814
#   :	:
#   (9986, 4452)	0.7095900229895048
#   (9988, 6016)	1.0
#   (9989, 6016)	1.0
#   (9990, 11931)	0.6859955012010418
#   (9990, 18051)	0.5041362646030758
#   (9990, 4923)	0.5246492152324153
#   (9991, 6016)	0.5469207655816869
#   (9991, 1448)	0.8371843740631699
#   (9992, 6016)	0.2972219142909323
#   (9992, 1564)	0.821048370180557
#   (9992, 15174)	0.48737942866834766
#   (9993, 6016)	0.40716389483453524
#   (9993, 1448)	0.6232552718594134
#   (9993, 15174)	0.6676604143145078
#   (9994, 6016)	1.0
#   (9995, 6016)	0.4181417023514885
#   (9995, 1448)	0.6400592579082733
#   (9995, 4452)	0.6445786710096058
#   (9996, 6016)	0.44045051269768754
#   (9996, 6872)	0.8977768909168603
#   (9997, 1448)	0.4355693700731073
#   (9997, 1564)	0.7860470598728986
#   (9997, 4452)	0.43864489455513833
#   (9998, 6016)	1.0
#   (9999, 4923)	1.0

# %%
#getting the similarity scores using cosine similarity
similarity = cosine_similarity(feature_vectors)
print(similarity)
# Out:
# [[1.         0.01444175 0.04714132 ... 0.         0.05809901 0.        ]
#  [0.01444175 1.         0.03495193 ... 0.04966871 0.         0.        ]
#  [0.04714132 0.03495193 1.         ... 0.11056719 0.03895791 0.        ]
#  ...
#  [0.         0.04966871 0.11056719 ... 1.         0.         0.        ]
#  [0.05809901 0.         0.03895791 ... 0.         1.         0.        ]
#  [0.         0.         0.         ... 0.         0.         1.        ]]

# %%
print(similarity.shape)
# Out:
# (10000, 10000)

# %%
#getting the movie name from the user
movie_name = input('Enter your favourite movie name: ')
# Out:
# Enter your favourite movie name: shakti

# %%
#creating a list with all the movie names given in the dataset
list_of_all_titles = movies_data['title'].tolist()
print(list_of_all_titles)
# Out:
# ['Freddy', 'An Action Hero', 'Kantara', 'Khakee: The Bihar Chapter', 'Drishyam 2', 'Qala', 'Bhediya', 'Goodbye', 'RRR (Rise Roar Revolt)', 'India Lockdown', 'Cat', 'Office Christmas Party', 'Chup', 'Dharavi Bank', 'Vadhandhi: The Fable of Velonie', 'Sita Ramam', 'Brahmastra Part One: Shiva', '1917', 'Nazar Andaaz', 'Love Today', 'College Romance', 'Monica O My Darling', 'Ready Player One', 'Mirzapur', 'Salaam Venky', 'Blurr', 'Ponniyin Selvan: I', 'Yashoda', 'DAMaN', 'Dhokha: Round D Corner', 'Godfather', 'The Help', 'Ram Setu', 'Raksha Bandhan', 'The Happening', '3 Idiots', 'HIT: The 2nd Case', 'Drishyam', 'Tanaav', 'Bridge of Spies', 'Mukhbir - The Story of a Spy', 'Monster', 'Vikram Vedha', 'Flames', 'Ghost in the Shell', 'The Turning', 'Breathe: Into the Shadows', 'Tumbbad', 'Finch', 'Dredd', 'Kumari', 'Life of Pi', 'Lincoln', 'Liger', 'Mismatched', 'Nitham Oru Vaanam', 'HIT: The First Case', 'Hit', 'The Girl on the Train', 'Lion', 'Uunchai', 'Kooman', 'Doctor G', 'Rorschach', 'Four More Shots Please!', 'Karthikeya 2', 'Laal Singh Chaddha', 'The Family Man', 'The Legend of Hanuman', 'Thank God', 'K.G.F: Chapter 2', 'I Am Number Four', 'The Bourne Supremacy', 'The Fall', 'Scam 1992: The Harshad Mehta Story', 'Padavettu', 'The Foreigner', 'Drishyam 2', 'Real Steel', 'The Trial of the Chicago 7', 'The BFG', 'War Horse', 'Cirkus', 'Bãhubali: The Beginning', 'Tapana', 'Panchayat', 'Crushed', 'Gandhi', 'Zakir Khan: Tathastu', 'Kabir Singh', 'Conan the Barbarian', 'Need for Speed', 'The Darjeeling Limited', 'Phone Bhoot', 'Iss Pyaar Ko Kya Naam Doon', 'Maarrich', 'Sacred Games', 'Kota Factory', 'Chhello Show', 'Cowboys & Aliens', '777 Charlie', 'Rocketry: The Nambi Effect', 'Major', 'TVF Pitchers', 'The Hundred-Foot Journey', 'Priest : The Whip and the Rise of the Evil', 'Pathaan', 'Pushpa: The Rise - Part 1', 'Gangubai Kathiawadi', 'Vikram', 'The Way Back', "A Dog's Purpose", 'Girls Hostel', 'Vadh', 'Jai Bhim', 'Fright Night', 'Cheppalani Undhi', 'Runway 34', 'Delhi Crime', 'Sultan', 'Jamtara: Sabka Number Ayega', 'Gold', 'Paatal Lok', 'Sardar', 'Tadka', 'Hostel Daze', 'Saudi Vellakka', 'Dobaaraa', 'Shooter', 'PK', 'The House with a Clock in Its Walls', 'Criminal Justice: Adhura Sach', 'Bulbbul', 'Baahubali 2: The Conclusion', 'Gatta Kusthi', 'Andhadhun', 'Shut In', 'Uri: The Surgical Strike', 'Miral', 'Lekh', 'The Kashmir Files', "A Dog's Journey", 'Special OPS', 'The Light Between Oceans', 'Dangerous', 'Mili', 'The White Tiger', 'Gangs of Wasseypur', 'Kaithi', 'Gullak', 'Apharan', 'Snowman', 'Suzhal - The Vortex', 'TVF Tripling', 'Dhoom:2', 'K.G.F: Chapter 1', 'Chhichhore', 'Faadu', 'Dangal', 'VR (Vikrant Rona)', 'Sir', 'All That Breathes', 'Jawan', 'The Teacher', 'Laila Majnu', 'Mastram', 'The Man Who Knew Infinity', 'ImMATURE', 'Ginna', 'Hush Hush', 'Darlings', 'The Reluctant Fundamentalist', 'Zindagi Na Milegi Dobara', 'Taare Zameen Par', 'Jug Jugg Jeeyo', 'Naagin', 'Kabhi Khushi Kabhie Gham...', 'Dilwale', 'She', 'Delivery Man', 'Dsp', 'Om Shanti Om', 'Maharani', 'Shiddat', 'Shamshera', 'Kal Ho Naa Ho', 'Kuch Kuch Hota Hai', 'Shershaah', 'Gadar: Ek Prem Katha', 'A Wednesday', 'Mimi', 'My Name Is Khan', 'Haseen Dillruba', 'Thiruchitrambalam', 'Bigg Boss', 'Badhaai Do', 'Cuttputlli', 'Smile', 'Raees', 'Stree', 'Dear Zindagi', 'Bimbisara', 'Batti Gul Meter Chalu', 'Khuda Haafiz Chapter II: Agni Pariksha', 'Har Har Mahadev', 'Moving in with Malaika', 'Come Play', 'Naai Sekar Returns', 'Pather Panchali', 'House of Secrets: The Burari Deaths', 'Comali', 'Swades: We, the People', 'Bullet to the Head', 'Aspirants', 'Jersey', 'Special Ops 1.5: The Himmat Story', 'Sardar Udham', 'Lagaan: Once Upon a Time in India', 'Mom', 'Devdas', 'Garuda Gamana Vrishabha Vahana', 'NCR Days', 'Mismatch', 'Lust Stories', 'Lucifer', 'Bride & Prejudice', 'Anek', 'Ek Villain Returns', 'Yeh Kaali Kaali Ankhein', 'Bajirao Mastani', 'Dilwale Dulhania Le Jayenge', 'Zero', 'Sonu Ke Titu Ki Sweety', 'Maja Ma', 'Jogi', 'Pratikshya', 'Tanhaji: The Unsung Warri ...

# %%
#finding the close match for the movie name given by user
find_close_match = difflib.get_close_matches(movie_name, list_of_all_titles)
print(find_close_match)
# Out:
# ['Shakti', 'Ashanti', 'Khaki']

# %%
close_match = find_close_match[0]
print(close_match)
# Out:
# Shakti

# %%
#finding the index of the movie with title
index_of_the_movie = movies_data[movies_data.title == close_match]['index'].values[0]
print(index_of_the_movie)
# Out:
# 3013

# %%
#getting a list of similar moviesw
similarity_score = list(enumerate(similarity[index_of_the_movie]))
print(similarity_score)
# Out:
# [(0, np.float64(0.005888246006826079)), (1, np.float64(0.012956443657325078)), (2, np.float64(0.04122604187291592)), (3, np.float64(0.002589373436735509)), (4, np.float64(0.020404666354834292)), (5, np.float64(0.025277226126624745)), (6, np.float64(0.012198834361409642)), (7, np.float64(0.008153036585286438)), (8, np.float64(0.005614029331218598)), (9, np.float64(0.011405762404036264)), (10, np.float64(0.052727060398034126)), (11, np.float64(0.025889068233973092)), (12, np.float64(0.012431280480628665)), (13, np.float64(0.015128273711637713)), (14, np.float64(0.042459136029505476)), (15, np.float64(0.0421050802993209)), (16, np.float64(0.010896842529425296)), (17, np.float64(0.04156071877353372)), (18, np.float64(0.010232837153458787)), (19, np.float64(0.011947548720752908)), (20, np.float64(0.003079873274629392)), (21, np.float64(0.021801324121484673)), (22, np.float64(0.010350131943360883)), (23, np.float64(0.007938471176569602)), (24, np.float64(0.015230858360169925)), (25, np.float64(0.0368141543592678)), (26, np.float64(0.014126505152973886)), (27, np.float64(0.0)), (28, np.float64(0.021420847384049795)), (29, np.float64(0.030247908697194535)), (30, np.float64(0.015424127461669646)), (31, np.float64(0.019980180287621465)), (32, np.float64(0.01673494655224109)), (33, np.float64(0.011507320146517784)), (34, np.float64(0.02484390907406008)), (35, np.float64(0.01125912515018587)), (36, np.float64(0.011984430801863474)), (37, np.float64(0.02155084268393342)), (38, np.float64(0.01948823517034052)), (39, np.float64(0.02655748196828907)), (40, np.float64(0.0678323994252765)), (41, np.float64(0.009885389885276425)), (42, np.float64(0.016541899397542196)), (43, np.float64(0.015546426409947432)), (44, np.float64(0.029151641829920177)), (45, np.float64(0.05998960303550911)), (46, np.float64(0.020922510342095166)), (47, np.float64(0.02007104255684049)), (48, np.float64(0.030703395740193484)), (49, np.float64(0.011397953279081045)), (50, np.float64(0.013638246695581804)), (51, np.float64(0.01915501767731122)), (52, np.float64(0.0346981800863476)), (53, np.float64(0.022963767075171088)), (54, np.float64(0.03322888307911647)), (55, np.float64(0.02460237520800119)), (56, np.float64(